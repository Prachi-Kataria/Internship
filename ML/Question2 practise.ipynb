# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/medical_cost_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/medical_cost_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.columns.tolist()
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
df.head(30)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df.tail(30)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1308   25  female  30.200         0    yes  southwest  33900.65300
# 1309   41    male  32.200         2     no  southwest   6875.96100
# 1310   42    male  26.315         1     no  northwest   6940.90985
# 1311   33  female  26.695         0     no  northwest   4571.41305
# 1312   34    male  42.900         1     no  southwest   4536.25900
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1315   18    male  28.310         1     no  northeast  11272.33139
# 1316   19  female  20.600         0     no  southwest   1731.67700
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1318   35    male  39.710         4     no  northeast  19496.71917
# 1319   39  female  26.315         2     no  northwest   7201.70085
# 1320   31    male  31.065         3     no  northwest   5425.02335
# ...

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['charges'].unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
df['charges'].nunique()
# Out:
# 1337

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# male      676
# female    662
# Name: sex, dtype: int64
#
#
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
#
#
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# no     1064
# yes     274
# Name: smoker, dtype: int64
#
#
# southeast    364
# ...

# %%
df.shape[0]
# Out:
# 1338

# %%
df.nunique().to_frame("No of Unique values")
# Out:
#           No of Unique values
# age                        47
# sex                         2
# bmi                       548
# children                    6
# smoker                      2
# region                      4
# charges                  1337

# %%
df['charges'].unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
df['charges'].value_counts()
# Out:
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
ax= sns.countplot(x='smoker',data=df)
print(df['smoker'].value_counts())
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
ax= sns.countplot(x='age',data=df)
print(df['age'].value_counts())
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
ax= sns.countplot(x='sex',data=df)
print(df['sex'].value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
ax= sns.countplot(x='region',data=df)
print(df['region'].value_counts())
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
ax= sns.countplot(x='bmi',data=df)
print(df['bmi'].value_counts())
# Out:
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64

# %%
ax= sns.countplot(x='children',data=df)
print(df['children'].value_counts())
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
plt.figure(figsize = (10,6), facecolor = "white")
plotnumber = 1
for col in numerical_col:
    if plotnumber<=4:
        ax = plt.subplot(2,2,plotnumber)   
        sns.distplot(df[col],color = "m")
        plt.xlabel(col, fontsize = 12)
        plt.yticks(rotation = 0,fontsize = 10)
    plotnumber+=1
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 plt.figure(figsize = (10,6), facecolor = "white")
#       2 plotnumber = 1
# ----> 3 for col in numerical_col:
#       4     if plotnumber<=4:
#       5         ax = plt.subplot(2,2,plotnumber)
#
# NameError: name 'numerical_col' is not defined

# %%
plt.figure(figsize = (10,6), facecolor = "white")
plotnumber = 1
for col in numerical_col:
    if plotnumber<=4:
        ax = plt.subplot(2,2,plotnumber)   
        sns.distplot(df[col],color = "m")
        plt.xlabel(col, fontsize = 12)
        plt.yticks(rotation = 0,fontsize = 10)
    plotnumber+=1
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 plt.figure(figsize = (10,6), facecolor = "white")
#       2 plotnumber = 1
# ----> 3 for col in numerical_col:
#       4     if plotnumber<=4:
#       5         ax = plt.subplot(2,2,plotnumber)
#
# NameError: name 'numerical_col' is not defined

# %%
numerical_col = df.select_dtypes(include=[np.number]).columns
plt.figure(figsize=(10, 6), facecolor="white")
plotnumber = 1
for col in numerical_col:
    if plotnumber <= 4:
        ax = plt.subplot(2, 2, plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize=12)
        plt.yticks(rotation=0, fontsize=10)
        plotnumber += 1
plt.tight_layout()

# %%
plt.title("comparison between smoker and charges")
sns.stripplot(x="smoker",y="charges",data=df)
plt.show()

# %%
plt.title("comparison between region and charges")
sns.stripplot(x="region",y="charges",data=df)
plt.show()

# %%
plt.title("comparison between sex and charges")
sns.stripplot(x="sex",y="charges",data=df)
plt.show()

# %%
plt.title("comparison between children and charges")
sns.stripplot(x="children",y="charges",data=df)
plt.show()

# %%
plt.title("comparison between smoker and charges")
sns.barplot(x="smoker",y="charges",data=df)
plt.show()

# %%
plt.title("comparison between sex and charges")
sns.barplot(x="sex",y="charges",data=df)
plt.show()

# %%
plt.title("comparison between region and charges")
sns.barplot(x="region",y="charges",data=df)
plt.show()

# %%
plt.title("comparison between children and charges")
sns.stripplot(x="children",y="charges",data=df)
plt.show()

# %%
sns.swarmplot(x='age',y='charges', data=df,palette="spring_r")
plt.show()

# %%
sns.swarmplot(x='bmi',y='charges', data=df,palette="spring_r")
plt.show()

# %%
sns.catplot(x='age',y='charges', data=df,palette="spring_r")
plt.show()

# %%
sns.pairplot(df,hue="smoker",palette="Dark2")
plt.show()

# %%
(Age and charges are lineraly dependent if age is more then the charges of Health Insurance is also more.The people with more age has to bear more charges and If age is less and he/she is smoking then also the charges of the health insurance is more

plt.figure(figsize=(10,6),facecolor="white")
plotnumber=1
for col in numerical_col:
    if plotnumber<=4:
           ax=plt.subplot(2,2,plotnumber)
           sns.boxplot(df[col],palette="Set2_r")
           plt.xlabel(col,fontsize=15)
           plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
In column charges and bmi outliers are present.so there is need of removing outliers. apart from these none of the coloumn have outliers.

df.skew()
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %%
df['charges']=np.cbrt(df['charges'])

# %%
df.skew()
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     0.515183
# dtype: float64

# %%
df['bmi']=np.cbrt(df['bmi'])

# %%
df.skew()
# Out:
# age         0.055673
# bmi        -0.075765
# children    0.938380
# charges     0.515183
# dtype: float64

# %%
sns.distplot(df['charges'],color="m",kde_kws = {"shade":True}, hist=False)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children      charges
# count  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     3.116088     1.094918    21.740315
# std      14.049960     0.208700     1.205493     6.609017
# min      18.000000     2.517740     0.000000    10.390777
# 25%      27.000000     2.973705     0.000000    16.798411
# 50%      39.000000     3.120982     1.000000    21.091088
# 75%      51.000000     3.261498     2.000000    25.529963
# max      64.000000     3.759354     5.000000    39.952115

# %%
cor=df.corr()
cor
# Out:
#                age       bmi  children   charges
# age       1.000000  0.114049  0.042469  0.451354
# bmi       0.114049  1.000000  0.012962  0.159305
# children  0.042469  0.012962  1.000000  0.123941
# charges   0.451354  0.159305  0.123941  1.000000
